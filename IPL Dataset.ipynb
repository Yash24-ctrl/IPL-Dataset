# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\kansa\Downloads\archive (18)\IPL_Matches_2008_2022.csv")

# %%
df.head(50)
# Out:
#          ID         City        Date Season  MatchNumber  \
# 0   1312200    Ahmedabad  2022-05-29   2022        Final
# 1   1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2   1312198      Kolkata  2022-05-25   2022   Eliminator
# 3   1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4   1304116       Mumbai  2022-05-22   2022           70
# 5   1304115       Mumbai  2022-05-21   2022           69
# 6   1304114       Mumbai  2022-05-20   2022           68
# 7   1304113       Mumbai  2022-05-19   2022           67
# 8   1304112  Navi Mumbai  2022-05-18   2022           66
# 9   1304111       Mumbai  2022-05-17   2022           65
# 10  1304110  Navi Mumbai  2022-05-16   2022           64
# 11  1304109       Mumbai  2022-05-15   2022           63
# 12  1304108       Mumbai  2022-05-15   2022           62
# 13  1304107         Pune  2022-05-14   2022           61
# 14  1304106       Mumbai  2022-05-13   2022           60
# ...

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.describe(include = "all")
# Out:
#                   ID    City        Date Season MatchNumber  \
# count   9.500000e+02     899         950    950         950
# unique           NaN      33         706     15          80
# top              NaN  Mumbai  2014-05-10   2013       Final
# freq             NaN     159           2     76          15
# mean    8.304852e+05     NaN         NaN    NaN         NaN
# std     3.375678e+05     NaN         NaN    NaN         NaN
# min     3.359820e+05     NaN         NaN    NaN         NaN
# 25%     5.012612e+05     NaN         NaN    NaN         NaN
# 50%     8.297380e+05     NaN         NaN    NaN         NaN
# 75%     1.175372e+06     NaN         NaN    NaN         NaN
# max     1.312200e+06     NaN         NaN    NaN         NaN
#
#                               Team1           Team2         Venue  \
# count                           950             950           950
# unique                           18              18            49
# ...

# %%
df['Date'].isnull().sum()
# Out:
# 0

# %%
df.dropna(how = "any", inplace = True)
df.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
df.head(50)
# Out:
#           ID           City        Date   Season MatchNumber  \
# 282  1136592          Delhi  2018-05-02     2018          32
# 296  1136578        Kolkata  2018-04-21     2018          18
# 308  1136566         Jaipur  2018-04-11     2018           6
# 316  1082648      Bangalore  2017-05-17     2017  Eliminator
# 383   980999      Bangalore  2016-05-18     2016          50
# 384   980997  Visakhapatnam  2016-05-17     2016          49
# 389   980989        Kolkata  2016-05-14     2016          45
# 411   980943      Hyderabad  2016-04-26     2016          22
# 441   829807      Hyderabad  2015-05-15     2015          52
# 472   829743  Visakhapatnam  2015-04-22     2015          19
# 520   733993          Delhi  2014-05-10     2014          32
# 717   501255      Bangalore  2011-05-14     2011          58
# 728   501245        Kolkata  2011-05-07     2011          48
# 757   501215          Kochi  2011-04-18     2011          18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, 282 to 910
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               19 non-null     int64
#  1   City             19 non-null     object
#  2   Date             19 non-null     object
#  3   Season           19 non-null     object
#  4   MatchNumber      19 non-null     object
#  5   Team1            19 non-null     object
#  6   Team2            19 non-null     object
#  7   Venue            19 non-null     object
#  8   TossWinner       19 non-null     object
#  9   TossDecision     19 non-null     object
#  10  SuperOver        19 non-null     object
#  11  WinningTeam      19 non-null     object
#  12  WonBy            19 non-null     object
#  13  Margin           19 non-null     float64
#  14  method           19 non-null     object
#  15  Player_of_Match  19 non-null     object
#  16  Team1Players     19 non-null     object
# ...

# %%
df.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
df.drop(["City" , "Date","Season",],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#           ID MatchNumber                        Team1  \
# 282  1136592          32             Delhi Daredevils
# 296  1136578          18        Kolkata Knight Riders
# 308  1136566           6             Rajasthan Royals
# 316  1082648  Eliminator          Sunrisers Hyderabad
# 383   980999          50  Royal Challengers Bangalore
# 384   980997          49      Rising Pune Supergiants
# 389   980989          45        Kolkata Knight Riders
# 411   980943          22          Sunrisers Hyderabad
# 441   829807          52          Sunrisers Hyderabad
# 472   829743          19          Sunrisers Hyderabad
#
#                            Team2  \
# 282             Rajasthan Royals
# 296              Kings XI Punjab
# 308             Delhi Daredevils
# 316        Kolkata Knight Riders
# 383              Kings XI Punjab
# 384             Delhi Daredevils
# 389      Rising Pune Supergiants
# 411      Rising Pune Supergiants
# 441  Royal Challengers Bangalore
# ...

# %%
df.Venue
# Out:
# 282                                 Arun Jaitley Stadium
# 296                                         Eden Gardens
# 308                               Sawai Mansingh Stadium
# 316                                M Chinnaswamy Stadium
# 383                                M Chinnaswamy Stadium
# 384    Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 389                                         Eden Gardens
# 411            Rajiv Gandhi International Stadium, Uppal
# 441            Rajiv Gandhi International Stadium, Uppal
# 472    Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 520                                     Feroz Shah Kotla
# 717                                M Chinnaswamy Stadium
# 728                                         Eden Gardens
# 757                                        Nehru Stadium
# 860                                      SuperSport Park
# 886                                            Kingsmead
# ...

# %%
df.isnull().sum()
# Out:
# ID                 0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
df_Venue=lambda x: str(x).split('/')[0]
df.Venue=df.Venue.apply(df_Venue)
df['Venue'].head()
# Out:
# 282      Arun Jaitley Stadium
# 296              Eden Gardens
# 308    Sawai Mansingh Stadium
# 316     M Chinnaswamy Stadium
# 383     M Chinnaswamy Stadium
# Name: Venue, dtype: object

# %%
df.head(3)
# Out:
#           ID MatchNumber                  Team1             Team2  \
# 282  1136592          32       Delhi Daredevils  Rajasthan Royals
# 296  1136578          18  Kolkata Knight Riders   Kings XI Punjab
# 308  1136566           6       Rajasthan Royals  Delhi Daredevils
#
#                       Venue        TossWinner TossDecision SuperOver  \
# 282    Arun Jaitley Stadium  Rajasthan Royals        field         N
# 296            Eden Gardens   Kings XI Punjab        field         N
# 308  Sawai Mansingh Stadium  Delhi Daredevils        field         N
#
#           WinningTeam    WonBy  Margin method Player_of_Match  \
# 282  Delhi Daredevils     Runs     4.0    D/L         RR Pant
# 296   Kings XI Punjab  Wickets     9.0    D/L        KL Rahul
# 308  Rajasthan Royals     Runs    10.0    D/L       SV Samson
#
#                                           Team1Players  \
# 282  ['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', '...
# ...

# %%
df.Margin
# Out:
# 282     4.0
# 296     9.0
# 308    10.0
# 316     7.0
# 383    82.0
# 384    19.0
# 389     8.0
# 411    34.0
# 441     6.0
# 472    16.0
# 520     8.0
# 717     4.0
# 728    10.0
# 757     7.0
# 860    12.0
# 886    11.0
# 889    10.0
# 908     3.0
# 910     6.0
# Name: Margin, dtype: float64

# %%
df["Margin"].unique()
# Out:
# array([ 4.,  9., 10.,  7., 82., 19.,  8., 34.,  6., 16., 12., 11.,  3.])

# %%
df['Margin']=df['Margin'].astype(str)
df['Margin']=df['Margin'].apply(lambda x:x.replace(',','.'))
df['Margin']=df['Margin'].astype(float)
df['Margin'].head()
# Out:
# 282     4.0
# 296     9.0
# 308    10.0
# 316     7.0
# 383    82.0
# Name: Margin, dtype: float64

# %%
df['Margin'] = df['Margin'].astype(str)
df['Margin'] = df['Margin'].apply(lambda x: x.replace(',','.'))
df['Margin'] = df['Margin'].astype(float)
df['Margin'] = df['Margin'].apply(lambda x: x/2)
df['Margin'].head()
# Out:
# 282     2.0
# 296     4.5
# 308     5.0
# 316     3.5
# 383    41.0
# Name: Margin, dtype: float64

# %%
df["TossWinner"].unique()
# Out:
# array(['Rajasthan Royals', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Kolkata Knight Riders', 'Rising Pune Supergiants',
#        'Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Chennai Super Kings', 'Kochi Tuskers Kerala'], dtype=object)

# %%
df['Margin']=df['Margin'].astype(str)
df['Margin']=df['Margin'].apply(lambda x:x.replace(',','.'))
df['Margin']=df['Margin'].astype(float)
df['Margin'].head()
# Out:
# 282     2.0
# 296     4.5
# 308     5.0
# 316     3.5
# 383    41.0
# Name: Margin, dtype: float64

# %%
df["Team1Players"].unique()
# Out:
# array(["['PP Shaw', 'C Munro', 'SS Iyer', 'RR Pant', 'GJ Maxwell', 'V Shankar', 'LE Plunkett', 'A Mishra', 'S Nadeem', 'Avesh Khan', 'TA Boult']",
#        "['CA Lynn', 'SP Narine', 'RV Uthappa', 'N Rana', 'KD Karthik', 'AD Russell', 'Shubman Gill', 'TK Curran', 'PP Chawla', 'Shivam Mavi', 'Kuldeep Yadav']",
#        "['AM Rahane', 'DJM Short', 'BA Stokes', 'SV Samson', 'JC Buttler', 'RA Tripathi', 'K Gowtham', 'S Gopal', 'DS Kulkarni', 'JD Unadkat', 'B Laughlin']",
#        "['DA Warner', 'S Dhawan', 'KS Williamson', 'Yuvraj Singh', 'V Shankar', 'NV Ojha', 'CJ Jordan', 'Bipul Sharma', 'B Kumar', 'Rashid Khan', 'S Kaul']",
#        "['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL Rahul', 'SR Watson', 'Sachin Baby', 'STR Binny', 'CJ Jordan', 'S Aravind', 'VR Aaron', 'YS Chahal']",
#        "['AM Rahane', 'UT Khawaja', 'GJ Bailey', 'SS Tiwary', 'IK Pathan', 'MS Dhoni', 'NLTC Perera', 'R Ashwin', 'A Zampa', 'AB Dinda', 'DL Chahar']",
# ...

# %%
df["Team2Players"].unique()
# Out:
# array(["['DJM Short', 'JC Buttler', 'SV Samson', 'BA Stokes', 'RA Tripathi', 'K Gowtham', 'JC Archer', 'AM Rahane', 'JD Unadkat', 'DS Kulkarni', 'S Gopal']",
#        "['KL Rahul', 'CH Gayle', 'MA Agarwal', 'KK Nair', 'AJ Finch', 'Yuvraj Singh', 'R Ashwin', 'AJ Tye', 'BB Sran', 'Mujeeb Ur Rahman', 'AS Rajpoot']",
#        "['GJ Maxwell', 'C Munro', 'RR Pant', 'CH Morris', 'V Shankar', 'SS Iyer', 'G Gambhir', 'R Tewatia', 'S Nadeem', 'TA Boult', 'Mohammed Shami']",
#        "['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gambhir', 'IR Jaggi', 'SA Yadav', 'SP Narine', 'PP Chawla', 'UT Yadav', 'NM Coulter-Nile', 'TA Boult']",
#        "['M Vijay', 'HM Amla', 'WP Saha', 'DA Miller', 'Gurkeerat Singh', 'AR Patel', 'F Behardien', 'KJ Abbott', 'MM Sharma', 'KC Cariappa', 'Sandeep Sharma']",
#        "['Q de Kock', 'SS Iyer', 'KK Nair', 'SV Samson', 'RR Pant', 'JP Duminy', 'CH Morris', 'NM Coulter-Nile', 'A Mishra', 'Z Khan', 'Mohammed Shami']",
# ...

# %%
df.ID
# Out:
# 282    1136592
# 296    1136578
# 308    1136566
# 316    1082648
# 383     980999
# 384     980997
# 389     980989
# 411     980943
# 441     829807
# 472     829743
# 520     733993
# 717     501255
# 728     501245
# 757     501215
# 860     392214
# 886     392186
# 889     392183
# 908     336025
# 910     336022
# Name: ID, dtype: int64

# %%
df_ID=lambda x: str(x).split('/')[0]
df.ID = df.ID.apply(df_ID)
df['ID'].head()
# Out:
# 282    1136592
# 296    1136578
# 308    1136566
# 316    1082648
# 383     980999
# Name: ID, dtype: object

# %%
df.head(10)
# Out:
#           ID MatchNumber                        Team1  \
# 282  1136592          32             Delhi Daredevils
# 296  1136578          18        Kolkata Knight Riders
# 308  1136566           6             Rajasthan Royals
# 316  1082648  Eliminator          Sunrisers Hyderabad
# 383   980999          50  Royal Challengers Bangalore
# 384   980997          49      Rising Pune Supergiants
# 389   980989          45        Kolkata Knight Riders
# 411   980943          22          Sunrisers Hyderabad
# 441   829807          52          Sunrisers Hyderabad
# 472   829743          19          Sunrisers Hyderabad
#
#                            Team2  \
# 282             Rajasthan Royals
# 296              Kings XI Punjab
# 308             Delhi Daredevils
# 316        Kolkata Knight Riders
# 383              Kings XI Punjab
# 384             Delhi Daredevils
# 389      Rising Pune Supergiants
# 411      Rising Pune Supergiants
# 441  Royal Challengers Bangalore
# ...

# %%
df.Margin
# Out:
# 282     2.0
# 296     4.5
# 308     5.0
# 316     3.5
# 383    41.0
# 384     9.5
# 389     4.0
# 411    17.0
# 441     3.0
# 472     8.0
# 520     4.0
# 717     2.0
# 728     5.0
# 757     3.5
# 860     6.0
# 886     5.5
# 889     5.0
# 908     1.5
# 910     3.0
# Name: Margin, dtype: float64

# %%
df['Margin'].unique()
# Out:
# array([ 2. ,  4.5,  5. ,  3.5, 41. ,  9.5,  4. , 17. ,  3. ,  8. ,  6. ,
#         5.5,  1.5])

# %%
df['Margin']=df['Margin'].astype(str)
df['Margin']=df['Margin'].apply(lambda x:x.replace(',','.'))
df['Margin']=df['Margin'].astype(float)
df['Margin'].head()
# Out:
# 282     2.0
# 296     4.5
# 308     5.0
# 316     3.5
# 383    41.0
# Name: Margin, dtype: float64

# %%
df['Margin']=df['Margin'].astype(str)
df['Margin']=df['Margin'].apply(lambda x:x.replace(',',','))
df['Margin']=df['Margin'].astype(float)
df['Margin']=df['Margin'].apply(lambda x: x/2)
df['Margin'].head()
# Out:
# 282     1.00
# 296     2.25
# 308     2.50
# 316     1.75
# 383    20.50
# Name: Margin, dtype: float64

# %%
df.shape
# Out:
# (19, 17)

# %%
df.size
# Out:
# 323

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           ID MatchNumber                        Team1  \
# 282  1136592          32             Delhi Daredevils
# 296  1136578          18        Kolkata Knight Riders
# 308  1136566           6             Rajasthan Royals
# 316  1082648  Eliminator          Sunrisers Hyderabad
# 383   980999          50  Royal Challengers Bangalore
# 384   980997          49      Rising Pune Supergiants
# 389   980989          45        Kolkata Knight Riders
# 411   980943          22          Sunrisers Hyderabad
# 441   829807          52          Sunrisers Hyderabad
# 472   829743          19          Sunrisers Hyderabad
# 520   733993          32             Delhi Daredevils
# 717   501255          58  Royal Challengers Bangalore
# 728   501245          48        Kolkata Knight Riders
# 757   501215          18         Kochi Tuskers Kerala
# 860   392214          34          Chennai Super Kings
# 886   392186           6              Kings XI Punjab
# ...

# %%
df.duplicated()
# Out:
# 282    False
# 296    False
# 308    False
# 316    False
# 383    False
# 384    False
# 389    False
# 411    False
# 441    False
# 472    False
# 520    False
# 717    False
# 728    False
# 757    False
# 860    False
# 886    False
# 889    False
# 908    False
# 910    False
# dtype: bool

# %%
def handel_ID(value):
    if(value=='NEW' or value=='_'):
        return np.nan
    else:
        value=str(value).split('/')
        value=value[0]
        return float(value)
df['ID']=df['ID'].apply(handel_ID)
df['ID'].head()
# Out:
# 282    1136592.0
# 296    1136578.0
# 308    1136566.0
# 316    1082648.0
# 383     980999.0
# Name: ID, dtype: float64

# %%
plt.subplots(figsize=(20,8))
sns.countplot(x = 'ID', data = df, palette='rainbow')
plt.title('ID numbers in list')
# Out:
# Text(0.5, 1.0, 'ID numbers in list')

# %%
fig = plt.figure(figsize=(20,10))
ax= fig.gca()

sns.boxplot(x = df['Margin'], y = df['Venue'])
plt.show()
